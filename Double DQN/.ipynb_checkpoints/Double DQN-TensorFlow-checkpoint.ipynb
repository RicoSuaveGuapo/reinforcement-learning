# %% [markdown]
# # DQN-TensorFlow

# %% [markdown]
# Here we use the `Keras` API of `TensorFlow2.0` to play `CartPole` game.

# %% [markdown]
# ### 1. Import Labraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %matplotlib inline
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 2. Define a class to store memory for training

# %% [markdown]
# This memory can store an experience $(state, action, reward, next state, terminal)$.
#
# Also it can sample some experiences for training.

# %%
class Memory:
    def __init__(self, size):
        self.memory_size = size
        self.memory = {
            's': None,
            'a': None,
            'r': None,
            's_': None,
            't': None
        }
    
    def store(self, s, a, r, s_, t):
        s = np.expand_dims(s, axis=0)  # add batch dimension
        a = np.array(a)
        r = np.array(r)
        s_ = np.expand_dims(s_, axis=0)  # add batch dimension
        t = np.array(t)
        
        if self.current_size >= self.memory_size:
            self.memory = self._delete(self.memory)
        
        if self.memory['s'] is None:
            self.memory['s'] = s
            self.memory['a'] = a
            self.memory['r'] = r
            self.memory['s_'] = s_
            self.memory['t'] = t
        else:
            self.memory['s'] = np.concatenate((self.memory['s'], s), axis=0)
            self.memory['a'] = np.hstack([self.memory['a'], a])
            self.memory['r'] = np.hstack([self.memory['r'], r])
            self.memory['s_'] = np.concatenate([self.memory['s_'], s_], axis=0)
            self.memory['t'] = np.hstack([self.memory['t'], t])
            
    def _delete(self, memory):
        # delete the first experience
        memory = {k: v[1:, ...] for k, v in memory.items()}
        assert len(memory['s']) <= self.memory_size
        
        return memory
    
    def sample(self, n, prioritized=False):
        if prioritized:
            raise NotImplementedError
        else:
            indices = np.random.choice(self.current_size, n)
            
        samples = {k: v[indices] for k, v in self.memory.items()}
        
        return samples
    
    @property
    def current_size(self):
        if self.memory['s'] is None:
            return 0
        else:
            return len(self.memory['s'])

# %% [markdown]
# ### 3. Define a class for deep Q network

# %%
class DQN:
    def __init__(self,
                 n_actions,
                 n_features,
                 learning_rate=0.001,
                 discount=0.9,
                 epsilon_greedy=0.9,
                 epsilon_greedy_increment=None,
                 update_target_iter=50,
                 memory_size=500,
                 batch_size=32
                ):
        self.n_actions = n_actions  # 2 for CartPole
        self.n_features = n_features  # 4 for CartPole
        self.learning_rate = learning_rate
        self.discount = discount
        self.batch_size = batch_size
        self.epsilon_max = epsilon_greedy
        self.epsilon_increment = epsilon_greedy_increment
        self.epsilon = 0 if epsilon_greedy_increment is not None else self.epsilon_max
        
        # record the times of training
        self.learn_steps = 0
        
        # fix the target Q network until `learn_steps` is a multiple of `update_target_iter`
        # otherwise, update the target Q network
        self.update_target_iter = update_target_iter
        
        # build a deep Q network and a traget Q network
        self._build()
        
        # build a memory
        self.memory = Memory(size=memory_size)
        
        self.loss_list = []
        
    def _build(self):
        self.q = tf.keras.models.Sequential()
        self.q.add(tf.keras.layers.Dense(32, activation='relu',
                                         input_shape=(self.n_features,)))
        self.q.add(tf.keras.layers.Dense(32, activation='relu'))
        # note that the activation function of the last layer can not be `sigmoid` or `softmax`
        # since it outputs q value that is not bounded in (0, 1)
        self.q.add(tf.keras.layers.Dense(self.n_actions, activation='linear'))
        
        # `q_target` has the same structure as `q` but has different weights
        self.q_target = tf.keras.models.clone_model(self.q)
        
        # make the weights of `q_target` the same as the weights of `q`
        self._update_target()
        
        # Use mean squared error as loss function since it is a regression problem
        # make q value close to target value
        self.q.compile(optimizer=tf.keras.optimizers.Adam(self.learning_rate),
                       loss=tf.keras.losses.mse
                      )
    
    def store(self, s, a, r, s_, t):
        # store memory
        self.memory.store(s, a, r, s_, t)
        
    def choose_action(self, s):
        s = np.expand_dims(s, axis=0)
        
        if np.random.uniform() < self.epsilon:
            q_value = self.q.predict(s)
            action = np.argmax(q_value)
        else:
            action = np.random.choice(self.n_actions)
            
        return action
        
    def learn(self):
        # update `q_target` every `update_target_iter`
        # otherwise, fix `q_target`
        if self.learn_steps % self.update_target_iter == 0:
            self._update_target()
        
        # sample a batch of training data
        memory_samples = self.memory.sample(self.batch_size)
        
        s = memory_samples['s']
        a = memory_samples['a']
        r = memory_samples['r']
        s_ = memory_samples['s_']
        t = memory_samples['t']
        
        
        q_target = self.q.predict(s)  # target q value
        q_next = self.q_target.predict(s_)  # q value of next state by `q_target`
        
        # replace the target q value corresponding the action selected by real target q value
        # the other values remain so that it is no matter when computing mse loss
        for i in range(len(q_target)):
            if t[i]:
                q_target[i, a[i]] = r[i]
            else:
                q_target[i, a[i]] = r[i] + self.discount * np.max(q_next[i])
        
        # update `q`
        loss = self.q.train_on_batch(s, q_target)
        self.loss_list.append(loss)
        
        # gradually increase the value of `epsilon`
        if self.epsilon_increment is not None:
            self.epsilon = self.epsilon + self.epsilon_increment
            self.epsilon = self.epsilon if self.epsilon < self.epsilon_max else self.epsilon_max
        self.learn_steps += 1
        
    def _update_target(self):
        # get the weights of `q`
        q_weights = self.q.get_weights()
        
        # assign the weights of q to `q_target`
        self.q_target.set_weights(q_weights)
        print('update_target')
        
    def plot_loss(self):
        plt.figure(figsize=(12, 6))
        plt.plot(np.arange(len(self.loss_list)), self.loss_list)
        plt.ylabel('Loss')
        plt.xlabel('training steps')
        plt.show()

# %% [markdown]
# ### 4. Let's train a DQN!

# %% [markdown]
# ##### 4.1 Create an environment

# %%
import gym
env = gym.make('CartPole-v1')
state = env.reset()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /Users/william/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# ##### 4.2 Create an actor

# %%
actor = DQN(n_actions=env.action_space.n,
            n_features=len(state),
            batch_size=32,
            discount=0.9,
            memory_size=1000,
            epsilon_greedy=1.0,
            epsilon_greedy_increment=0.001
           )
# Out:
# update_target

# %% [markdown]
# ##### 4.3 Train the actor

# %%
step = 0
rewards = []

for episode in range(500):
    period = 0
    total_reward = 0
    
    state = env.reset()
    
    while True:
        env.render()
        
        # actor chooses an action
        action = actor.choose_action(state)
        
        # use the action to update the environment
        state_next, reward, done, info = env.step(action)
        
        # if game is over, set reward = -1
        # if game is not over, reward = +1
        if done:
            reward = - reward
        
        total_reward += reward
        
        # store this experience
        actor.store(state, action, reward, state_next, done)
        
        # train your actor if it has 100 or more experiences
        # train your actor every 5 steps
        # you can tune these value by yourself
        if step > 100 and step % 5 == 0:
            actor.learn()
        
        # jump to next state
        state = state_next
        
        if done:
            break
        step += 1
        period += 1
    
    print('Episode: {:3d}, reward: {:3d}, epsilon: {:.4f}'.format(episode, int(total_reward), actor.epsilon))
    rewards.append(total_reward)

print('game over')
# Out:
# Episode:   0, reward:  13, epsilon: 0.0000
# update_target
# Episode: 188, reward:  96, epsilon: 1.0000
# Episode: 189, reward: 103, epsilon: 1.0000
# update_target
# Episode: 190, reward: 179, epsilon: 1.0000
# Episode: 191, reward:  47, epsilon: 1.0000
# Episode: 192, reward: 109, epsilon: 1.0000
# update_target
# Episode: 193, reward:  78, epsilon: 1.0000
# Episode: 194, reward:  85, epsilon: 1.0000
# update_target
# Episode: 195, reward: 143, epsilon: 1.0000
# Episode: 196, reward: 100, epsilon: 1.0000
# Episode: 197, reward:  99, epsilon: 1.0000
# update_target
# Episode: 198, reward:  75, epsilon: 1.0000
# Episode: 199, reward: 127, epsilon: 1.0000
# update_target
# Episode: 200, reward: 211, epsilon: 1.0000
# update_target
# Episode: 201, reward: 245, epsilon: 1.0000
# Episode: 202, reward: 104, epsilon: 1.0000
# update_target
# Episode: 203, reward: 194, epsilon: 1.0000
# update_target
# Episode: 204, reward: 200, epsilon: 1.0000
# Episode: 205, reward: 115, epsilon: 1.0000
# update_target
# Episode: 206, reward: 146, epsilon: 1.0000
# update_target
# Episode: 207, reward: 248, epsilon: 1.0000
# update_target
# Episode: 208, reward: 146, epsilon: 1.0000
# update_target
# Episode: 209, reward: 264, epsilon: 1.0000
# update_target
# Episode: 210, reward: 251, epsilon: 1.0000
# update_target
# Episode: 211, reward: 425, epsilon: 1.0000
# update_target
# Episode: 212, reward: 205, epsilon: 1.0000
# update_target
# update_target
# Episode: 213, reward: 326, epsilon: 1.0000
# Episode: 214, reward: 226, epsilon: 1.0000
# update_target
# update_target
# Episode: 215, reward: 293, epsilon: 1.0000
# update_target
# update_target
# Episode: 216, reward: 498, epsilon: 1.0000
# Episode: 217, reward: 191, epsilon: 1.0000
# update_target
# update_target
# Episode: 218, reward: 333, epsilon: 1.0000
# update_target
# Episode: 219, reward: 191, epsilon: 1.0000
# update_target
# Episode: 220, reward: 242, epsilon: 1.0000
# Episode: 221, reward: 225, epsilon: 1.0000
# update_target
# update_target
# Episode: 222, reward: 338, epsilon: 1.0000
# update_target
# Episode: 223, reward: 224, epsilon: 1.0000
# update_target
# Episode: 224, reward: 221, epsilon: 1.0000
# Episode: 225, reward: 217, epsilon: 1.0000
# update_target
# Episode: 226, reward: 240, epsilon: 1.0000
# update_target
# Episode: 227, reward: 250, epsilon: 1.0000
# update_target
# Episode: 228, reward: 205, epsilon: 1.0000
# update_target
# Episode: 229, reward: 227, epsilon: 1.0000
# update_target
# Episode: 230, reward: 320, epsilon: 1.0000
# update_target
# update_target
# Episode: 231, reward: 336, epsilon: 1.0000
# update_target
# update_target
# Episode: 232, reward: 498, epsilon: 1.0000
# update_target
# Episode: 233, reward: 222, epsilon: 1.0000
# update_target
# update_target
# Episode: 234, reward: 462, epsilon: 1.0000
# update_target
# update_target
# Episode: 235, reward: 498, epsilon: 1.0000
# update_target
# Episode: 236, reward: 289, epsilon: 1.0000
# update_target
# Episode: 237, reward: 327, epsilon: 1.0000
# update_target
# Episode: 238, reward: 180, epsilon: 1.0000
# update_target
# Episode: 239, reward: 334, epsilon: 1.0000
# update_target
# Episode: 240, reward: 236, epsilon: 1.0000
# update_target
# Episode: 241, reward: 256, epsilon: 1.0000
# update_target
# Episode: 242, reward: 315, epsilon: 1.0000
# update_target
# update_target
# Episode: 243, reward: 304, epsilon: 1.0000
# update_target
# Episode: 244, reward: 267, epsilon: 1.0000
# update_target
# Episode: 245, reward: 381, epsilon: 1.0000
# update_target
# update_target
# Episode: 246, reward: 379, epsilon: 1.0000
# update_target
# Episode: 247, reward: 430, epsilon: 1.0000
# update_target
# update_target
# Episode: 248, reward: 418, epsilon: 1.0000
# update_target
# update_target
# Episode: 249, reward: 408, epsilon: 1.0000
# update_target
# Episode: 250, reward: 384, epsilon: 1.0000
# update_target
# Episode: 251, reward: 284, epsilon: 1.0000
# update_target
# Episode: 252, reward: 254, epsilon: 1.0000
# update_target
# update_target
# Episode: 253, reward: 373, epsilon: 1.0000
# update_target
# update_target
# Episode: 254, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 255, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 256, reward: 410, epsilon: 1.0000
# update_target
# Episode: 257, reward: 354, epsilon: 1.0000
# update_target
# update_target
# Episode: 258, reward: 381, epsilon: 1.0000
# update_target
# Episode: 259, reward: 334, epsilon: 1.0000
# update_target
# update_target
# Episode: 260, reward: 477, epsilon: 1.0000
# update_target
# update_target
# Episode: 261, reward: 483, epsilon: 1.0000
# update_target
# Episode: 262, reward: 419, epsilon: 1.0000
# update_target
# update_target
# Episode: 263, reward: 490, epsilon: 1.0000
# update_target
# update_target
# Episode: 264, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 265, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 266, reward: 452, epsilon: 1.0000
# update_target
# update_target
# Episode: 267, reward: 498, epsilon: 1.0000
# update_target
# Episode: 268, reward: 265, epsilon: 1.0000
# update_target
# update_target
# Episode: 269, reward: 323, epsilon: 1.0000
# update_target
# update_target
# Episode: 270, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 271, reward: 489, epsilon: 1.0000
# update_target
# update_target
# Episode: 272, reward: 498, epsilon: 1.0000
# update_target
# Episode: 273, reward: 450, epsilon: 1.0000
# update_target
# Episode: 274, reward: 246, epsilon: 1.0000
# update_target
# Episode: 275, reward: 179, epsilon: 1.0000
# update_target
# Episode: 276, reward: 283, epsilon: 1.0000
# update_target
# Episode: 277, reward: 215, epsilon: 1.0000
# update_target
# Episode: 278, reward: 289, epsilon: 1.0000
# update_target
# Episode: 279, reward: 160, epsilon: 1.0000
# update_target
# Episode: 280, reward: 186, epsilon: 1.0000
# update_target
# Episode: 281, reward: 218, epsilon: 1.0000
# Episode: 282, reward: 183, epsilon: 1.0000
# update_target
# Episode: 283, reward: 187, epsilon: 1.0000
# update_target
# Episode: 284, reward: 306, epsilon: 1.0000
# update_target
# Episode: 285, reward: 274, epsilon: 1.0000
# update_target
# update_target
# Episode: 286, reward: 287, epsilon: 1.0000
# update_target
# Episode: 287, reward: 441, epsilon: 1.0000
# update_target
# update_target
# Episode: 288, reward: 295, epsilon: 1.0000
# update_target
# Episode: 289, reward: 488, epsilon: 1.0000
# update_target
# Episode: 290, reward: 254, epsilon: 1.0000
# update_target
# Episode: 291, reward: 200, epsilon: 1.0000
# update_target
# Episode: 292, reward: 250, epsilon: 1.0000
# update_target
# Episode: 293, reward: 165, epsilon: 1.0000
# update_target
# Episode: 294, reward: 185, epsilon: 1.0000
# Episode: 295, reward: 152, epsilon: 1.0000
# update_target
# Episode: 296, reward: 178, epsilon: 1.0000
# update_target
# Episode: 297, reward: 151, epsilon: 1.0000
# Episode: 298, reward: 107, epsilon: 1.0000
# update_target
# Episode: 299, reward: 161, epsilon: 1.0000
# Episode: 300, reward: 130, epsilon: 1.0000
# update_target
# Episode: 301, reward: 149, epsilon: 1.0000
# Episode: 302, reward: 144, epsilon: 1.0000
# update_target
# Episode: 303, reward: 142, epsilon: 1.0000
# update_target
# Episode: 304, reward: 153, epsilon: 1.0000
# Episode: 305, reward:  18, epsilon: 1.0000
# Episode: 306, reward: 119, epsilon: 1.0000
# update_target
# Episode: 307, reward: 125, epsilon: 1.0000
# Episode: 308, reward:  17, epsilon: 1.0000
# Episode: 309, reward: 131, epsilon: 1.0000
# Episode: 310, reward:  15, epsilon: 1.0000
# Episode: 311, reward:  17, epsilon: 1.0000
# update_target
# Episode: 312, reward:  14, epsilon: 1.0000
# Episode: 313, reward:   9, epsilon: 1.0000
# Episode: 314, reward:  10, epsilon: 1.0000
# Episode: 315, reward:  10, epsilon: 1.0000
# Episode: 316, reward:  10, epsilon: 1.0000
# Episode: 317, reward:   7, epsilon: 1.0000
# Episode: 318, reward:   8, epsilon: 1.0000
# Episode: 319, reward:   9, epsilon: 1.0000
# Episode: 320, reward:  10, epsilon: 1.0000
# Episode: 321, reward:   9, epsilon: 1.0000
# Episode: 322, reward:   8, epsilon: 1.0000
# Episode: 323, reward:  12, epsilon: 1.0000
# update_target
# Episode: 324, reward: 121, epsilon: 1.0000
# Episode: 325, reward:   7, epsilon: 1.0000
# Episode: 326, reward:  10, epsilon: 1.0000
# Episode: 327, reward:  12, epsilon: 1.0000
# update_target
# Episode: 328, reward: 223, epsilon: 1.0000
# Episode: 329, reward: 184, epsilon: 1.0000
# Episode: 330, reward:  18, epsilon: 1.0000
# Episode: 331, reward:  18, epsilon: 1.0000
# update_target
# Episode: 332, reward:  20, epsilon: 1.0000
# Episode: 333, reward:  18, epsilon: 1.0000
# update_target
# Episode: 334, reward: 258, epsilon: 1.0000
# Episode: 335, reward:  33, epsilon: 1.0000
# Episode: 336, reward:  79, epsilon: 1.0000
# Episode: 337, reward:  83, epsilon: 1.0000
# update_target
# Episode: 338, reward:  86, epsilon: 1.0000
# Episode: 339, reward:  32, epsilon: 1.0000
# Episode: 340, reward:  28, epsilon: 1.0000
# Episode: 341, reward:  49, epsilon: 1.0000
# update_target
# Episode: 342, reward: 110, epsilon: 1.0000
# Episode: 343, reward:  47, epsilon: 1.0000
# Episode: 344, reward: 122, epsilon: 1.0000
# update_target
# update_target
# Episode: 345, reward: 343, epsilon: 1.0000
# update_target
# update_target
# Episode: 346, reward: 466, epsilon: 1.0000
# update_target
# update_target
# Episode: 347, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 348, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 349, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 350, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 351, reward: 498, epsilon: 1.0000
# update_target
# Episode: 352, reward: 378, epsilon: 1.0000
# update_target
# update_target
# Episode: 353, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 354, reward: 498, epsilon: 1.0000
# update_target
# Episode: 355, reward: 312, epsilon: 1.0000
# update_target
# update_target
# Episode: 356, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 357, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 358, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 359, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 360, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 361, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 362, reward: 414, epsilon: 1.0000
# update_target
# Episode: 363, reward: 197, epsilon: 1.0000
# update_target
# Episode: 364, reward: 198, epsilon: 1.0000
# update_target
# Episode: 365, reward: 411, epsilon: 1.0000
# update_target
# update_target
# Episode: 366, reward: 359, epsilon: 1.0000
# update_target
# update_target
# Episode: 367, reward: 454, epsilon: 1.0000
# Episode: 368, reward: 174, epsilon: 1.0000
# update_target
# Episode: 369, reward: 270, epsilon: 1.0000
# update_target
# Episode: 370, reward: 176, epsilon: 1.0000
# update_target
# Episode: 371, reward: 301, epsilon: 1.0000
# update_target
# Episode: 372, reward: 151, epsilon: 1.0000
# Episode: 373, reward: 127, epsilon: 1.0000
# update_target
# Episode: 374, reward: 126, epsilon: 1.0000
# update_target
# Episode: 375, reward: 136, epsilon: 1.0000
# Episode: 376, reward: 108, epsilon: 1.0000
# Episode: 377, reward: 117, epsilon: 1.0000
# update_target
# Episode: 378, reward: 132, epsilon: 1.0000
# Episode: 379, reward: 130, epsilon: 1.0000
# update_target
# Episode: 380, reward: 110, epsilon: 1.0000
# Episode: 381, reward: 135, epsilon: 1.0000
# update_target
# Episode: 382, reward: 129, epsilon: 1.0000
# update_target
# Episode: 383, reward: 127, epsilon: 1.0000
# Episode: 384, reward: 113, epsilon: 1.0000
# update_target
# Episode: 385, reward: 128, epsilon: 1.0000
# Episode: 386, reward: 107, epsilon: 1.0000
# Episode: 387, reward: 109, epsilon: 1.0000
# update_target
# Episode: 388, reward: 114, epsilon: 1.0000
# Episode: 389, reward: 103, epsilon: 1.0000
# update_target
# Episode: 390, reward:  86, epsilon: 1.0000
# Episode: 391, reward: 136, epsilon: 1.0000
# update_target
# Episode: 392, reward: 108, epsilon: 1.0000
# Episode: 393, reward: 100, epsilon: 1.0000
# Episode: 394, reward: 108, epsilon: 1.0000
# update_target
# Episode: 395, reward: 115, epsilon: 1.0000
# Episode: 396, reward: 125, epsilon: 1.0000
# update_target
# Episode: 397, reward: 116, epsilon: 1.0000
# Episode: 398, reward: 108, epsilon: 1.0000
# update_target
# Episode: 399, reward: 145, epsilon: 1.0000
# Episode: 400, reward: 103, epsilon: 1.0000
# update_target
# Episode: 401, reward: 164, epsilon: 1.0000
# update_target
# Episode: 402, reward: 124, epsilon: 1.0000
# Episode: 403, reward: 164, epsilon: 1.0000
# update_target
# Episode: 404, reward: 163, epsilon: 1.0000
# Episode: 405, reward: 130, epsilon: 1.0000
# update_target
# Episode: 406, reward: 135, epsilon: 1.0000
# Episode: 407, reward: 123, epsilon: 1.0000
# update_target
# Episode: 408, reward: 152, epsilon: 1.0000
# update_target
# Episode: 409, reward: 138, epsilon: 1.0000
# Episode: 410, reward: 186, epsilon: 1.0000
# update_target
# Episode: 411, reward: 213, epsilon: 1.0000
# update_target
# Episode: 412, reward: 165, epsilon: 1.0000
# Episode: 413, reward: 149, epsilon: 1.0000
# update_target
# Episode: 414, reward: 154, epsilon: 1.0000
# update_target
# Episode: 415, reward: 320, epsilon: 1.0000
# update_target
# update_target
# Episode: 416, reward: 295, epsilon: 1.0000
# update_target
# Episode: 417, reward: 295, epsilon: 1.0000
# update_target
# Episode: 418, reward: 295, epsilon: 1.0000
# update_target
# update_target
# Episode: 419, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 420, reward: 498, epsilon: 1.0000
# update_target
# Episode: 421, reward: 257, epsilon: 1.0000
# update_target
# Episode: 422, reward: 333, epsilon: 1.0000
# update_target
# update_target
# Episode: 423, reward: 354, epsilon: 1.0000
# update_target
# Episode: 424, reward: 256, epsilon: 1.0000
# update_target
# Episode: 425, reward: 427, epsilon: 1.0000
# update_target
# update_target
# Episode: 426, reward: 394, epsilon: 1.0000
# update_target
# Episode: 427, reward: 292, epsilon: 1.0000
# update_target
# update_target
# Episode: 428, reward: 345, epsilon: 1.0000
# update_target
# Episode: 429, reward: 466, epsilon: 1.0000
# update_target
# update_target
# Episode: 430, reward: 263, epsilon: 1.0000
# update_target
# Episode: 431, reward: 483, epsilon: 1.0000
# update_target
# update_target
# Episode: 432, reward: 304, epsilon: 1.0000
# update_target
# Episode: 433, reward: 256, epsilon: 1.0000
# update_target
# Episode: 434, reward: 220, epsilon: 1.0000
# update_target
# Episode: 435, reward: 240, epsilon: 1.0000
# update_target
# Episode: 436, reward: 255, epsilon: 1.0000
# update_target
# Episode: 437, reward: 285, epsilon: 1.0000
# update_target
# Episode: 438, reward: 186, epsilon: 1.0000
# Episode: 439, reward: 195, epsilon: 1.0000
# update_target
# Episode: 440, reward: 218, epsilon: 1.0000
# update_target
# Episode: 441, reward: 191, epsilon: 1.0000
# update_target
# update_target
# Episode: 442, reward: 386, epsilon: 1.0000
# Episode: 443, reward: 199, epsilon: 1.0000
# update_target
# Episode: 444, reward: 169, epsilon: 1.0000
# update_target
# Episode: 445, reward: 189, epsilon: 1.0000
# Episode: 446, reward: 160, epsilon: 1.0000
# update_target
# Episode: 447, reward: 155, epsilon: 1.0000
# update_target
# Episode: 448, reward: 178, epsilon: 1.0000
# Episode: 449, reward: 171, epsilon: 1.0000
# update_target
# Episode: 450, reward: 179, epsilon: 1.0000
# update_target
# Episode: 451, reward: 132, epsilon: 1.0000
# Episode: 452, reward: 136, epsilon: 1.0000
# update_target
# Episode: 453, reward: 142, epsilon: 1.0000
# Episode: 454, reward: 168, epsilon: 1.0000
# update_target
# Episode: 455, reward: 150, epsilon: 1.0000
# update_target
# Episode: 456, reward: 155, epsilon: 1.0000
# update_target
# Episode: 457, reward: 259, epsilon: 1.0000
# Episode: 458, reward: 159, epsilon: 1.0000
# update_target
# Episode: 459, reward: 147, epsilon: 1.0000
# update_target
# Episode: 460, reward: 219, epsilon: 1.0000
# update_target
# Episode: 461, reward: 155, epsilon: 1.0000
# Episode: 462, reward: 210, epsilon: 1.0000
# update_target
# update_target
# Episode: 463, reward: 275, epsilon: 1.0000
# Episode: 464, reward: 173, epsilon: 1.0000
# update_target
# Episode: 465, reward: 188, epsilon: 1.0000
# update_target
# Episode: 466, reward: 257, epsilon: 1.0000
# update_target
# Episode: 467, reward: 188, epsilon: 1.0000
# update_target
# Episode: 468, reward: 179, epsilon: 1.0000
# Episode: 469, reward: 198, epsilon: 1.0000
# update_target
# Episode: 470, reward: 171, epsilon: 1.0000
# update_target
# Episode: 471, reward: 272, epsilon: 1.0000
# update_target
# Episode: 472, reward: 152, epsilon: 1.0000
# update_target
# Episode: 473, reward: 201, epsilon: 1.0000
# Episode: 474, reward: 198, epsilon: 1.0000
# update_target
# update_target
# Episode: 475, reward: 372, epsilon: 1.0000
# update_target
# Episode: 476, reward: 215, epsilon: 1.0000
# update_target
# Episode: 477, reward: 332, epsilon: 1.0000
# update_target
# update_target
# Episode: 478, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 479, reward: 498, epsilon: 1.0000
# update_target
# update_target
# Episode: 480, reward: 498, epsilon: 1.0000
# update_target
# Episode: 481, reward: 355, epsilon: 1.0000
# update_target
# update_target
# Episode: 482, reward: 389, epsilon: 1.0000
# update_target
# Episode: 483, reward: 203, epsilon: 1.0000
# update_target
# Episode: 484, reward: 278, epsilon: 1.0000
# update_target
# Episode: 485, reward: 170, epsilon: 1.0000
# Episode: 486, reward: 176, epsilon: 1.0000
# update_target
# Episode: 487, reward: 198, epsilon: 1.0000
# update_target
# Episode: 488, reward: 149, epsilon: 1.0000
# update_target
# Episode: 489, reward: 214, epsilon: 1.0000
# update_target
# update_target
# Episode: 490, reward: 498, epsilon: 1.0000
# update_target
# Episode: 491, reward: 304, epsilon: 1.0000
# update_target
# Episode: 492, reward: 259, epsilon: 1.0000
# update_target
# Episode: 493, reward: 293, epsilon: 1.0000
# update_target
# Episode: 494, reward: 252, epsilon: 1.0000
# update_target
# Episode: 495, reward: 306, epsilon: 1.0000
# update_target
# update_target
# Episode: 496, reward: 391, epsilon: 1.0000
# update_target
# update_target
# Episode: 497, reward: 432, epsilon: 1.0000
# update_target
# Episode: 498, reward: 305, epsilon: 1.0000
# update_target
# Episode: 499, reward: 322, epsilon: 1.0000
# game over

# %% [markdown]
# ##### 4.4 Plot the loss and the reward

# %%
actor.plot_loss()

# %%
plt.figure(figsize=(12, 6))
plt.plot(rewards, label='reward')
plt.plot([195] * len(rewards), c='r', linestyle='--', label='195')
plt.xlabel('training steps')
plt.ylabel('reward before game over')
plt.legend();

# %% [markdown]
# ### 5. Let's test your actor

# %%
frames = []
rewards = []

for episode in range(100):
    total_reward = 0
    
    state = env.reset()
    
    while True:
        # only collect the grame of the first episode
        if episode == 0:
            frame = env.render(mode='rgb_array')
            frames.append(frame)
        
        action = actor.choose_action(state)
        state_next, reward, done, info = env.step(action)
        
        total_reward += reward

        actor.store(state, action, reward, state_next, done)
            
        state = state_next
        
        if done:
            break
    
    print('Episode: {:3d}, reward: {:3d}'.format(episode, int(total_reward)))
    rewards.append(total_reward)

print('game over')
# Out:
# Episode:   0, reward: 189
# Episode:   1, reward: 194
# Episode:   2, reward: 188
# Episode:   3, reward: 209
# Episode:   4, reward: 181
# Episode:   5, reward: 195
# Episode:   6, reward: 203
# Episode:   7, reward: 192
# Episode:   8, reward: 191
# Episode:   9, reward: 208
# Episode:  10, reward: 195
# Episode:  11, reward: 195
# Episode:  12, reward: 191
# Episode:  13, reward: 191
# Episode:  14, reward: 203
# Episode:  15, reward: 185
# Episode:  16, reward: 193
# Episode:  17, reward: 201
# Episode:  18, reward: 188
# Episode:  19, reward: 193
# Episode:  20, reward: 189
# Episode:  21, reward: 199
# Episode:  22, reward: 194
# Episode:  23, reward: 188
# Episode:  24, reward: 204
# Episode:  25, reward: 200
# Episode:  26, reward: 189
# Episode:  27, reward: 195
# Episode:  28, reward: 190
# Episode:  29, reward: 190
# Episode:  30, reward: 193
# Episode:  31, reward: 193
# Episode:  32, reward: 194
# Episode:  33, reward: 195
# Episode:  34, reward: 192
# Episode:  35, reward: 202
# Episode:  36, reward: 192
# Episode:  37, reward: 193
# Episode:  38, reward: 199
# Episode:  39, reward: 201
# Episode:  40, reward: 190
# Episode:  41, reward: 187
# Episode:  42, reward: 189
# Episode:  43, reward: 197
# Episode:  44, reward: 204
# Episode:  45, reward: 193
# Episode:  46, reward: 194
# Episode:  47, reward: 200
# Episode:  48, reward: 183
# Episode:  49, reward: 195
# Episode:  50, reward: 204
# Episode:  51, reward: 202
# Episode:  52, reward: 185
# Episode:  53, reward: 196
# Episode:  54, reward: 196
# Episode:  55, reward: 190
# Episode:  56, reward: 197
# Episode:  57, reward: 197
# Episode:  58, reward: 198
# Episode:  59, reward: 197
# Episode:  60, reward: 202
# Episode:  61, reward: 201
# Episode:  62, reward: 190
# Episode:  63, reward: 201
# Episode:  64, reward: 200
# Episode:  65, reward: 188
# Episode:  66, reward: 197
# Episode:  67, reward: 199
# Episode:  68, reward: 193
# Episode:  69, reward: 192
# Episode:  70, reward: 199
# Episode:  71, reward: 202
# Episode:  72, reward: 196
# Episode:  73, reward: 195
# Episode:  74, reward: 194
# Episode:  75, reward: 191
# Episode:  76, reward: 190
# Episode:  77, reward: 207
# Episode:  78, reward: 185
# Episode:  79, reward: 193
# Episode:  80, reward: 192
# Episode:  81, reward: 204
# Episode:  82, reward: 193
# Episode:  83, reward: 204
# Episode:  84, reward: 200
# Episode:  85, reward: 204
# Episode:  86, reward: 206
# Episode:  87, reward: 196
# Episode:  88, reward: 199
# Episode:  89, reward: 200
# Episode:  90, reward: 202
# Episode:  91, reward: 183
# Episode:  92, reward: 200
# Episode:  93, reward: 197
# Episode:  94, reward: 197
# Episode:  95, reward: 197
# Episode:  96, reward: 200
# Episode:  97, reward: 188
# Episode:  98, reward: 192
# Episode:  99, reward: 196
# game over

# %% [markdown]
# ##### Wow! Your actor is so smart!

# %%
plt.figure(figsize=(12, 6))
plt.plot(rewards, label='reward')
plt.plot([195] * len(rewards), c='r', linestyle='--', label='195')
plt.xlabel('steps')
plt.ylabel('reward before game over')
plt.title('CartPole-v1')
plt.legend();

# %% [markdown]
# ### 6. Let's generate an animation to show off XDDD

# %%
from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import display
from JSAnimation.IPython_display import display_animation
# %matplotlib inline

# %%
def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    display(display_animation(anim, default_mode='loop'))
    
    return anim

# %%
def save_animation(anim, savepath):
    assert savepath.endswith('.mp4')
    
    Writer = animation.writers['ffmpeg']
    writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)
    anim.save(savepath, writer=writer)
    
    print('Save animation completed')

# %%
anim = display_frames_as_gif(frames)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgHLYQQODDWLAONKBQ">
#     <br>
#     <input id="_anim_sliderHLYQQODDWLAONKBQ" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animHLYQQODDWLAONKBQ.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animHLYQQODDWLAONKBQ.slower()">&#8211;</button>
#     <button onclick="animHLYQQODDWLAONKBQ.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animHLYQQODDWLAONKBQ.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectHLYQQODDWLAONKBQ" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgHLYQQODDWLAONKBQ";
#     var slider_id = "_anim_sliderHLYQQODDWLAONKBQ";
#     var loop_select_id = "_anim_loop_selectHLYQQODDWLAONKBQ";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
save_animation(anim, savepath='dqn_cartpole.mp4')
# Out:
# Save animation completed
