# %% [markdown]
# # Policy Gradient-TensorFlow

# %% [markdown]
# Here we use the `Keras` API of `TensorFlow2.0` to play `MountainCar` game.

# %% [markdown]
# # Implementation of policy gradient using TensorFlow-2.0
#
# Policy gradient is a basic algorithm of Reinforcement Learning (RL) that can be adopted in continuous or discrete problems. It can be found somewhere in several advanced RL algorithms such as A2C, A3C, and so on.
#
# # Theory
#
# Policy gradient algorithm trains a policy to play a game. A policy is a function that inputs states and outputs the probability of every action:
#
# $
# p(a|s) = \pi(a|s)
# $
#
# , where $s \in \mathcal{S}$ is a given state and $a \in \mathcal{A}$ is an action. We can use a neural network to construct our policy.
#
# The goal of a policy is to maximize the expected cumulated reward in an episode. In every episode a policy would receive a series of rewards, and we often use a constant called $\gamma$ as hyperparameter to cumulate all rewards
#
# $
# R_\theta = \sum^T_{t=1} r_t
# $
#
# where $\theta$ indicates the parameters of the neural neywork. Then the expected cumulated reward is given by
#
# $
# \bar{R}_\theta = \mathbb{E}[R_\theta] = \sum_\tau R(\tau)P(\tau|\theta)
# $
#
# where $\tau$ denotes the “trajectory” of an episode:
# $\tau = \left\{ s_1, a_1, r_1, s_2, a_2, r_2, \cdots, s_T, a_T, r_T \right\}$.
#
# So the goal becomes to find the best parameters $\theta$ in order to maximize $\bar{R}_\theta$:
#
# $
# \theta^* = \arg \max_\theta \bar{R}_\theta
# $
#
# Therefore, we can use ***gradient ascent*** to update the parameters $\theta$:
#
# $
# \theta_{t+1} = \theta_t + \eta \nabla \bar{R}_{\theta_t}
# $
#
# Next, we write $\nabla \bar{R}_\theta$ explicitly:
#
# $
# \nabla \bar{R}_\theta
# = \nabla \sum_\tau R(\tau) P(\tau|\theta) \\
# = \sum_\tau R(\tau) \nabla P(\tau|\theta) \\
# = \sum_\tau R(\tau) P(\tau|\theta) \frac{\nabla P(\tau|\theta)}{P(\tau|\theta)} \\
# = \sum_\tau R(\tau) P(\tau|\theta) \nabla \ln P(\tau|\theta) \\
# \approx \frac{1}{N} \sum_\tau R(\tau) \nabla \ln P(\tau|\theta)
# $
#
# , if there are $N$ episodes.
#
# Then we rewrite $P(\tau|\theta)$ as the product of transition probabilities and action probabilities that the policy produces:
#
# $
# P(\tau|\theta)
# = p(s_1) \times \pi(a_1|s_1;\theta) \times p(r_1,s_2|s_1,a_1) \times \pi(a_2|s_2;\theta) \times \cdots \\
# = p(s_1) \prod^T_{t=1} \pi(a_t|s_t;\theta) p(r_t,s_{t+1}|s_t,a_t) \\
# \ln P(\tau|\theta) = \ln p(s_1) + \sum^T_{t=1} \ln \pi(a_t|s_t;\theta) + \ln p(r_t,s_{t+1}|s_t,a_t)
# $
#
# So
#
# $
# \nabla \ln P(\tau|\theta) = \sum^T_{t=1} \nabla \ln \pi(a_t|s_t;\theta)
# $
#
# Substitude the result back and we get
#
# $
# \nabla \bar{R}_\theta
# \approx \frac{1}{N} \sum_\tau R(\tau) \nabla \ln P(\tau|\theta) \\
# \approx \frac{1}{N} \sum_\tau \sum^{T_\tau}_{t=1} R(\tau) \nabla \ln \pi(a_t|s_t;\theta)
# $

# %% [markdown]
# ### 1. Import Labraries

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %matplotlib inline
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 2. Define a class to store memory for training

# %% [markdown]
# This memory can store an experience $(state, action, reward)$ for training after episode is completed.

# %%
class Memory:
    
    def __init__(self):
        self.states = []
        self.actions = []
        self.rewards = []
        
    def store(self, s, a, r):
        self.states.append(s)
        self.actions.append(a)
        self.rewards.append(r)
    
    def withdraw(self):
        return self.states, self.actions, self.rewards
        
    def clear(self):
        self.states = []
        self.actions = []
        self.rewards = []

# %% [markdown]
# ### 3. Define a class for policy gradient

# %%
class PolicyGradient:
    
    def __init__(self,
                 n_actions,
                 n_features,
                 learning_rate=0.001,
                 discount=0.9
                ):
        self.n_actions = n_actions
        self.n_features = n_features
        self.lr = learning_rate
        self.gamma = discount
        self.memory = Memory()
        
        self._build_model()
        
    def _build_model(self):
        self.model = tf.keras.Sequential()
        self.model.add(tf.keras.layers.Dense(16, activation='relu',
                                             input_shape=(self.n_features,)))
        self.model.add(tf.keras.layers.Dense(16, activation='relu'))
        self.model.add(tf.keras.layers.Dense(self.n_actions, activation=None))
        
        self.optimizer = tf.keras.optimizers.Adam(self.lr)
    
    def _convert_one_hot(self, actions):
        return np.eye(self.n_actions)[actions]
        
    def _process_rewards(self, rewards):
        processed_rewards = np.zeros_like(rewards, dtype=np.float32)
        
        G = 0
        for t in reversed(range(len(rewards))):
            G = rewards[t] + self.gamma * G
            processed_rewards[t] = G
            
        processed_rewards -= np.mean(processed_rewards)
        processed_rewards /= np.std(processed_rewards)
        
        return tf.convert_to_tensor(processed_rewards)
    
    def _grad(self, states, actions, rewards):
        with tf.GradientTape() as tape:
            loss_value = self._loss(states, actions, rewards)
        return tape.gradient(loss_value, self.model.trainable_variables)
        
    def _loss(self, states, actions, rewards):
        states = tf.convert_to_tensor(states)
        
        logits_actions = self.model(states)  # can not use self.model.predict(states)
        labels_actions = tf.convert_to_tensor(actions)
        modify_rewards = self._process_rewards(rewards)
        
        neg_log_prob = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=actions ,logits=logits_actions)
        
        return tf.reduce_mean(modify_rewards * neg_log_prob)
        
    def store(self, state, action, reward):
        self.memory.store(state, action, reward)
    
    def choose_action(self, state):
        state = np.expand_dims(state, axis=0)
        probs = self.model.predict(state)  # (1, n_actions)
        probs = np.exp(probs)  # (1, n_actions)
        probs /= np.sum(probs)
        action = np.random.choice(self.n_actions, p=probs.ravel())
        
        return action
    
    def learn(self):
        states, actions, rewards = self.memory.withdraw()
        
        grads = self._grad(states, actions, rewards)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        
        self.memory.clear()
        
    def save(self, path):
        self.model.save_weights(path)
        print('Saved!')
        
    def restore(self, path):
        self.model.load_weights(path)
        print('Loaded!')

# %% [markdown]
# ### 4. Let's train an actor!

# %% [markdown]
# ##### 4.1 Create an environment

# %%
env = gym.make('MountainCar-v0')
state = env.reset()
state
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /Users/william/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# array([-0.40239543,  0.        ])

# %% [markdown]
# ##### 4.2 Create an actor

# %%
actor = PolicyGradient(n_actions=env.action_space.n, n_features=len(state), discount=0.9)

# %% [markdown]
# ##### 4.3 Custom rewards

# %% [markdown]
# Since the reward for mountain car is sparse. And we know that sparse reward may lead difficult training since actor has no direction to learn.
#
# Instead of sparse reward, we define our custom reward that appears more frequently in order to train our actor fast. Our custom reward is defined in the way so that more fast the car is, and more right position the car can reach, more high the reward is.

# %%
def modify_reward(state):
    x, v = state
    
    reward = 50 * v**2
    
    if x > 0.20:
        reward += 1
    if x > 0.30:
        reward += 1
    if x > 0.40:
        reward += 1
    if x > 0.45:
        reward += 1
            
    return reward

# %% [markdown]
# ##### 4.4 Train the actor

# %%
step = 0
periods = []
rewards = []

for episode in range(5000):
    period = 0
    total_reward = 0
    
    state = env.reset()
    
    while True:
        env.render()
        
        action = actor.choose_action(state)
        next_state, reward, done, info = env.step(action)
        reward = modify_reward(state)
        
        total_reward += reward
        
        actor.store(state, action, reward)
        
        state = next_state
        
        if done:
            actor.learn()
            break
            
        step += 1
        period += 1
    
    if episode % 10 == 0:
        print('Episode: {:3d}, period: {:3d}, reward: {:3.3f}'.format(episode, period, total_reward))
    rewards.append(total_reward)

print('game over')
# Out:
# Episode:   0, period: 199, reward: 0.308
# Episode:  10, period: 199, reward: 0.467
# Episode:  20, period: 199, reward: 0.286
# Episode:  30, period: 199, reward: 0.153
# Episode:  40, period: 199, reward: 0.333
# Episode:  50, period: 199, reward: 0.944
# Episode:  60, period: 199, reward: 0.546
# Episode:  70, period: 199, reward: 0.257
# Episode:  80, period: 199, reward: 0.417
# Episode:  90, period: 199, reward: 0.036
# Episode: 100, period: 199, reward: 0.550
# Episode: 110, period: 199, reward: 0.323
# Episode: 120, period: 199, reward: 0.804
# Episode: 130, period: 199, reward: 0.598
# Episode: 140, period: 199, reward: 1.428
# Episode: 150, period: 199, reward: 0.108
# Episode: 160, period: 199, reward: 0.409
# Episode: 170, period: 199, reward: 0.304
# Episode: 180, period: 199, reward: 0.449
# Episode: 190, period: 199, reward: 0.522
# Episode: 200, period: 199, reward: 0.709
# Episode: 210, period: 199, reward: 0.162
# Episode: 220, period: 199, reward: 0.559
# Episode: 230, period: 199, reward: 0.982
# Episode: 240, period: 199, reward: 0.791
# Episode: 250, period: 199, reward: 0.259
# Episode: 260, period: 199, reward: 0.394
# Episode: 270, period: 199, reward: 0.394
# Episode: 280, period: 199, reward: 0.530
# Episode: 290, period: 199, reward: 0.344
# Episode: 300, period: 199, reward: 0.230
# Episode: 310, period: 199, reward: 0.124
# Episode: 320, period: 199, reward: 1.053
# Episode: 330, period: 199, reward: 0.455
# Episode: 340, period: 199, reward: 0.897
# Episode: 350, period: 199, reward: 0.219
# Episode: 360, period: 199, reward: 0.487
# Episode: 370, period: 199, reward: 0.202
# Episode: 380, period: 199, reward: 0.277
# Episode: 390, period: 199, reward: 0.050
# Episode: 400, period: 199, reward: 1.020
# Episode: 410, period: 199, reward: 0.540
# Episode: 420, period: 199, reward: 0.147
# Episode: 430, period: 199, reward: 0.666
# Episode: 440, period: 199, reward: 0.840
# Episode: 450, period: 199, reward: 0.210
# Episode: 460, period: 199, reward: 0.570
# Episode: 470, period: 199, reward: 0.775
# Episode: 480, period: 199, reward: 0.706
# Episode: 4720, period: 181, reward: 25.597
# Episode: 4730, period: 199, reward: 1.362
# Episode: 4740, period: 190, reward: 20.983
# Episode: 4750, period: 199, reward: 1.092
# Episode: 4760, period: 150, reward: 27.962
# Episode: 4770, period: 145, reward: 44.382
# Episode: 4780, period: 199, reward: 4.010
# Episode: 4790, period: 179, reward: 24.290
# Episode: 4800, period: 154, reward: 73.150
# Episode: 4810, period: 199, reward: 90.695
# Episode: 4820, period: 199, reward: 1.130
# Episode: 4830, period: 188, reward: 22.449
# Episode: 4840, period: 178, reward: 21.286
# Episode: 4850, period: 199, reward: 5.240
# Episode: 4860, period: 178, reward: 20.548
# Episode: 4870, period: 118, reward: 35.659
# Episode: 4880, period: 199, reward: 10.885
# Episode: 4890, period: 199, reward: 4.909
# Episode: 4900, period: 199, reward: 2.724
# Episode: 4910, period: 199, reward: 3.199
# Episode: 4920, period: 199, reward: 21.837
# Episode: 4930, period: 199, reward: 1.596
# Episode: 4940, period: 199, reward: 1.039
# Episode: 4950, period: 199, reward: 1.960
# Episode: 4960, period: 199, reward: 4.026
# Episode: 4970, period: 199, reward: 6.789
# Episode: 4980, period: 199, reward: 6.955
# Episode: 4990, period: 199, reward: 27.928
# game over

# %% [markdown]
# ##### 4.5 Save the model

# %%
actor.save(path='model.ckpt')
# Out:
# Saved!

# %% [markdown]
# ##### 4.5 Plot the reward

# %%
plt.figure(figsize=(12, 6))
plt.plot(rewards, label='reward')
plt.xlabel('training steps')
plt.ylabel('modified reward');

# %% [markdown]
# ### 5. Let's test our actor

# %% [markdown]
# ##### 5.1 Restore the model

# %%
actor = PolicyGradient(n_actions=env.action_space.n, n_features=len(state), discount=0.9)
actor.restore('model.ckpt')
# Out:
# Loaded!

# %% [markdown]
# ##### 5.2 run 100 episodes

# %%
rewards = []
total_frames = []

for episode in range(100):
    frames = []
    total_reward = 0
    
    state = env.reset()
    
    while True:
        frame = env.render(mode='rgb_array')
        frames.append(frame)
        
        action = actor.choose_action(state)
        state_next, reward, done, info = env.step(action)
        
        total_reward += reward
        
        state = state_next
        
        if done:
            break
    
    print('Episode: {:3d}, reward: {:3d}'.format(episode, int(total_reward)))
    total_frames.append(frames)
    rewards.append(total_reward)

print('game over')
# Out:
# Episode:   0, reward: -158
# Episode:   1, reward: -200
# Episode:   2, reward: -199
# Episode:   3, reward: -188
# Episode:   4, reward: -200
# Episode:   5, reward: -200
# Episode:   6, reward: -164
# Episode:   7, reward: -175
# Episode:   8, reward: -184
# Episode:   9, reward: -147
# Episode:  10, reward: -200
# Episode:  11, reward: -182
# Episode:  12, reward: -181
# Episode:  13, reward: -200
# Episode:  14, reward: -188
# Episode:  15, reward: -200
# Episode:  16, reward: -143
# Episode:  17, reward: -200
# Episode:  18, reward: -194
# Episode:  19, reward: -142
# Episode:  20, reward: -189
# Episode:  21, reward: -200
# Episode:  22, reward: -200
# Episode:  23, reward: -177
# Episode:  24, reward: -200
# Episode:  25, reward: -198
# Episode:  26, reward: -147
# Episode:  27, reward: -185
# Episode:  28, reward: -180
# Episode:  29, reward: -200
# Episode:  30, reward: -186
# Episode:  31, reward: -200
# Episode:  32, reward: -184
# Episode:  33, reward: -181
# Episode:  34, reward: -184
# Episode:  35, reward: -194
# Episode:  36, reward: -123
# Episode:  37, reward: -195
# Episode:  38, reward: -190
# Episode:  39, reward: -153
# Episode:  40, reward: -181
# Episode:  41, reward: -120
# Episode:  42, reward: -153
# Episode:  43, reward: -148
# Episode:  44, reward: -171
# Episode:  45, reward: -184
# Episode:  46, reward: -200
# Episode:  47, reward: -200
# Episode:  48, reward: -157
# Episode:  49, reward: -173
# Episode:  50, reward: -200
# Episode:  51, reward: -172
# Episode:  52, reward: -200
# Episode:  53, reward: -145
# Episode:  54, reward: -152
# Episode:  55, reward: -200
# Episode:  56, reward: -200
# Episode:  57, reward: -200
# Episode:  58, reward: -154
# Episode:  59, reward: -196
# Episode:  60, reward: -193
# Episode:  61, reward: -155
# Episode:  62, reward: -186
# Episode:  63, reward: -200
# Episode:  64, reward: -187
# Episode:  65, reward: -200
# Episode:  66, reward: -200
# Episode:  67, reward: -193
# Episode:  68, reward: -143
# Episode:  69, reward: -200
# Episode:  70, reward: -184
# Episode:  71, reward: -196
# Episode:  72, reward: -180
# Episode:  73, reward: -183
# Episode:  74, reward: -190
# Episode:  75, reward: -194
# Episode:  76, reward: -165
# Episode:  77, reward: -190
# Episode:  78, reward: -153
# Episode:  79, reward: -200
# Episode:  80, reward: -200
# Episode:  81, reward: -183
# Episode:  82, reward: -195
# Episode:  83, reward: -200
# Episode:  84, reward: -149
# Episode:  85, reward: -200
# Episode:  86, reward: -193
# Episode:  87, reward: -200
# Episode:  88, reward: -200
# Episode:  89, reward: -180
# Episode:  90, reward: -184
# Episode:  91, reward: -137
# Episode:  92, reward: -189
# Episode:  93, reward: -189
# Episode:  94, reward: -184
# Episode:  95, reward: -175
# Episode:  96, reward: -180
# Episode:  97, reward: -164
# Episode:  98, reward: -200
# Episode:  99, reward: -142
# game over

# %%
plt.figure(figsize=(12, 6))
plt.plot(rewards, label='reward')
plt.xlabel('episode')
plt.ylabel('reward')
plt.title('MountainCar-v0');

# %% [markdown]
# ### 6. Let's generate an animation to show off

# %%
from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import display
from JSAnimation.IPython_display import display_animation
# %matplotlib inline

# %%
# choose the best run
best_run = np.argmax(total_reward)
frames = total_frames[best_run]

# %%
def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    display(display_animation(anim, default_mode='loop'))
    
    return anim

# %%
def save_animation(anim, savepath):
    assert savepath.endswith('.mp4')
    
    Writer = animation.writers['ffmpeg']
    writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)
    anim.save(savepath, writer=writer)
    
    print('Save animation completed')

# %%
anim = display_frames_as_gif(frames)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgULFKLJHVELCOIAWD">
#     <br>
#     <input id="_anim_sliderULFKLJHVELCOIAWD" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animULFKLJHVELCOIAWD.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animULFKLJHVELCOIAWD.slower()">&#8211;</button>
#     <button onclick="animULFKLJHVELCOIAWD.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animULFKLJHVELCOIAWD.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectULFKLJHVELCOIAWD" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgULFKLJHVELCOIAWD";
#     var slider_id = "_anim_sliderULFKLJHVELCOIAWD";
#     var loop_select_id = "_anim_loop_selectULFKLJHVELCOIAWD";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
save_animation(anim, savepath='policy_gradient_mountaincar.mp4')
# Out:
# Save animation completed
